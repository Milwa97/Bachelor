# %%
from program import *

# %%
display(GUI)

# %%
#run_simulation()
# Out:
# nlinks =  10
# Xinit =  10
# c =  0.11
# lambd =  1.0
# initial range 5 before:
# IN UPDATE
#
#
# cell =  (0, 0, 3, False) next 3
# cell =  (0, 2, 3, False) next 3
# cell =  (0, 10, 3, False) next 3
# cell =  (0, 17, 3, False) next 3
# cell =  (0, 23, 3, False) next 3
# cell =  (1, 3, 3, False) next 3
# cell =  (1, 14, 3, False) next 3
# cell =  (1, 19, 3, False) next 3
# cell =  (2, 16, 3, False) next 3
# cell =  (2, 24, 3, False) next 3
# cell =  (3, 1, 3, False) next 3
# cell =  (3, 6, 3, False) next 3
# cell =  (3, 7, 3, False) next 3
# cell =  (3, 15, 3, False) next 3
# cell =  (4, 12, 3, False) next 3
# cell =  (4, 13, 3, False) next 3
# cell =  (5, 13, 3, False) next 3
# cell =  (6, 0, 3, False) next 3
# cell =  (6, 11, 3, False) next 3
# cell =  (6, 17, 3, False) next 3
# cell =  (6, 22, 3, False) next 3
# cell =  (7, 4, 3, False) next 3
# cell =  (7, 18, 3, False) next 3
# cell =  (7, 24, 3, False) next 3
# cell =  (8, 11, 3, False) next 3
# cell =  (8, 21, 3, False) next 3
# ...

# %%
run_simulation()
# Out:
# nlinks =  10
# Xinit =  10
# c =  0.11
# lambd =  1.0
# initial range 5 before:
# IN UPDATE
#
#
# cell =  (0, 4, 3, False) next 3
# cell =  (0, 15, 3, False) next 3
# cell =  (0, 20, 3, False) next 3
# cell =  (2, 4, 3, False) next 3
# cell =  (2, 24, 3, False) next 3
# cell =  (3, 9, 3, False) next 3
# cell =  (3, 10, 3, False) next 3
# cell =  (3, 11, 3, False) next 3
# cell =  (3, 13, 3, False) next 3
# cell =  (3, 18, 3, False) next 3
# cell =  (3, 23, 3, False) next 3
# cell =  (4, 1, 3, False) next 3
# cell =  (4, 10, 3, False) next 3
# cell =  (4, 21, 3, False) next 3
# cell =  (5, 3, 3, False) next 3
# cell =  (5, 8, 3, False) next 3
# cell =  (5, 15, 3, False) next 3
# cell =  (5, 17, 3, False) next 3
# cell =  (7, 1, 3, False) next 3
# cell =  (7, 15, 3, False) next 3
# cell =  (7, 18, 3, False) next 3
# cell =  (8, 6, 3, False) next 3
# cell =  (8, 10, 3, False) next 3
# cell =  (8, 13, 3, False) next 3
# cell =  (8, 24, 3, False) next 3
# cell =  (9, 5, 3, False) next 3
# ...
