# %%
from base import *

# %%
df_9 = read_data('n9c15X50l07.csv')
df_18 = read_data('n18c15X50l07.csv')
df_45 = read_data('n45c15X50l07.csv')
df_90 = read_data('n90c15X50l07.csv')
df_180 = read_data('n180c15X50l07.csv')
df_450 = read_data('n450c15X50l07.csv')
df_900 = read_data('n900c15X50l07.csv')

df_0 = read_data('n0c15X50l07.csv')

n_bars = 40

# %%
single_histogram(df_9, df_0, k = n_bars, start_value = 10, n = 9,
                 limit = [450, 450, 450, 450, 450, 450, 450])

# %%
single_histogram(df_18, df_0, k = n_bars, start_value = 10, n = 18,
                 limit = [450, 450, 450, 450, 450, 450, 450])

# %%
single_histogram(df_45, df_0, k = n_bars, start_value = 10, n = 45,
                 limit = [450, 450, 450, 450, 450, 450, 450])

# %%
single_histogram(df_90, df_0, k = n_bars, start_value = 10, n = 90,
                 limit = [450, 450, 450, 450, 450, 450, 450])

# %%
single_histogram(df_180, df_0, k = n_bars, start_value = 10, n = 180,
                 limit = [450, 450, 450, 450, 450, 450, 450])

# %%
single_histogram(df_450, df_0, k = n_bars, start_value = 10, n = 450,
                 limit = [450, 450, 450, 450, 450, 450, 450])

# %%
single_histogram(df_900, df_0, k = n_bars, start_value = 10, n = 900,
                limit = [450, 450, 450, 450, 450, 450, 450])
