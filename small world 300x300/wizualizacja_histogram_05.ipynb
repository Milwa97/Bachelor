# %%
from base import *

# %%
#df_9 = read_data('n9c15X50l05.csv')
df_18 = read_data('n18c15X50l05.csv')
df_45 = read_data('n45c15X50l05.csv')
df_90 = read_data('n90c15X50l05.csv')
df_180 = read_data('n180c15X50l05.csv')
df_450 = read_data('n450c15X50l05.csv')
df_900 = read_data('n900c15X50l05.csv')

df_0 = read_data('n0c15X50l05.csv')

n_bars = 20
# Out:
# WARNING! Less than 400 samples in file: n18c15X50l05.csv, k = 291
# WARNING! Less than 400 samples in file: n0c15X50l05.csv, k = 130

# %%
single_histogram(df_18, df_0, k = n_bars, start_value = 10, n = 18,
                 limit = [800, 800, 800, 800, 800, 800, 800])

# %%
single_histogram(df_45, df_0, k = n_bars, start_value = 10, n = 45,
                 limit = [800, 800, 800, 800, 800, 800, 800])

# %%
single_histogram(df_90, df_0, k = n_bars, start_value = 10, n = 90,
                 limit = [800, 800, 800, 800, 800, 800, 800])

# %%
single_histogram(df_180, df_0, k = n_bars, start_value = 10, n = 180,
                limit = [800, 800, 800, 800, 800, 800, 800])

# %%
single_histogram(df_450, df_0, k = n_bars, start_value = 10, n = 450,
                limit = [800, 800, 800, 800, 800, 800, 800])

# %%
single_histogram(df_900, df_0, k = n_bars, start_value = 10, n = 900,
                 limit = [800, 800, 800, 800, 800, 800, 800])

# %% [markdown]
# # Multihistograms

# %%
multi_histogram(df_180, df_450, df_900, df_0, k = n_bars, start_value = 10, n_names = ['180', '450', '900'], interval = 10,
                limit = [800, 800, 800, 800, 800, 800, 800], filename = 'c15X50l1.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7a0127677c20> in <module>
# ----> 1 multi_histogram(df_180, df_450, df_900, df_0, k = n_bars, start_value = 10, n_names = ['180', '450', '900'], interval = 10,
#       2                 limit = [800, 800, 800, 800, 800, 800, 800], filename = 'c15X50l1.png')
#
# NameError: name 'multi_histogram' is not defined

# %%
multi_histogram_3(df_180, df_450, df_900, df_0, k = n_bars, start_value = 60, n_names = ['180', '450', '900'], interval = 10,
                limit = [800, 800, 800, 800, 800, 800, 800], filename = 'c15X50l1.png')
